# %% [markdown]
# <a href="https://colab.research.google.com/github/Psyhoved/MCHackaton_22_MVP_team_04/blob/main/MCH_22_MVP_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/drive/MyDrive/MCH_2022/data.csv')
data
# Out:
#                                client_id gender  birth_date create_date  \
# 0       fe60b594364f9f636266ed1ef4f89c32      Ж        1985  2020-01-29
# 1       3012cabca5885ed53d348d6e57dab5de      М        1951  2009-09-24
# 2       d871ef96820b6c7a1ada8e01a772724e      Ж        1982  2006-12-25
# 3       0bacbc2abd314f9fac031d249e485a7b      М        1955  2011-04-15
# 4       0bacbc2abd314f9fac031d249e485a7b      М        1955  2011-04-15
# ...                                  ...    ...         ...         ...
# 371578  d69d3201104ab393c0638839a7284ad7      М        1953  2018-08-08
# 371579  a936fb30e2268d2874cdcaa221032915      М        1997  2022-05-12
# 371580  a9cf0bb4f06fa321704ced777e993b33      М        1983  2021-10-15
# 371581  f69eb17242ca85eb21349dc08220afb8      Ж        1986  2022-02-12
# 371582  93237191eddf8dec77cc947c3c086358      Ж        1959  2012-07-19
#
#        nonresident_flag  businessman_flag              city  term  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371583 entries, 0 to 371582
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   client_id                371583 non-null  object
#  1   gender                   371583 non-null  object
#  2   birth_date               371583 non-null  int64
#  3   create_date              371583 non-null  object
#  4   nonresident_flag         371583 non-null  object
#  5   businessman_flag         371583 non-null  int64
#  6   city                     370415 non-null  object
#  7   term                     0 non-null       float64
#  8   contract_sum             371583 non-null  float64
#  9   product_category_name    371583 non-null  object
#  10  card_id                  371583 non-null  object
#  11  card_type_name           318638 non-null  object
#  12  start_date               318638 non-null  float64
# ...

# %%
data.describe()
# Out:
#           birth_date  businessman_flag  term  contract_sum     start_date  \
# count  371583.000000          371583.0   0.0  3.715830e+05  318638.000000
# mean     1978.405368               0.0   NaN  1.257979e+04    2019.414935
# std        14.195167               0.0   NaN  1.317040e+05       1.566411
# min      1927.000000               0.0   NaN  0.000000e+00    2013.000000
# 25%      1968.000000               0.0   NaN  0.000000e+00    2018.000000
# 50%      1980.000000               0.0   NaN  0.000000e+00    2020.000000
# 75%      1989.000000               0.0   NaN  0.000000e+00    2021.000000
# max      2010.000000               0.0   NaN  1.061710e+07    2022.000000
#
#        fact_close_date  purchase_sum  purchase_count  current_balance_avg_sum  \
# count    132176.000000  3.715830e+05   371583.000000             3.715830e+05
# mean       2020.601864  6.449207e+03        8.309522             2.965146e+04
# ...

# %%
всвкакпииииииииииииииииииииииииии# удаляем пустые колонки
data.drop(columns=('businessman_flag', 'term'), inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-93727bbf65a1> in <module>()
# ----> 1 data.drop(columns=('businessman_flag', 'term'), inplace = True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
sns.pairplot(data)

# %%
data['gender'].value_counts().plot.bar()

# %%
sns.barplot(data= data, x='gender', y='contract_sum')

# %%
sns.barplot(data= data, x='gender', y='purchase_sum')

# %%
sns.barplot(data= data, x='gender', y='purchase_count')

# %%
sns.barplot(data= data, x='gender', y='current_balance_avg_sum')

# %%
sns.barplot(data= data, x='gender', y='current_balance_sum')

# %%
sns.barplot(data= data, x='gender', y='current_debit_turn_sum')
